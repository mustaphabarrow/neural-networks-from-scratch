# %% [markdown]
# # Forward Pass: From Single Neuron to Layer
#
# This notebook demonstrates how a neural network computes outputs starting from:
# - A single neuron
# - Multiple neurons
# - Using loops
# - Using NumPy (dot product)
#
# The goal is to understand the core operation:
#
# output = inputs · weights + bias

# %% [markdown]
# Code (Cell 2 — Single Neuron)

# %%
# Single neuron with 3 inputs
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2

output = inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias
print("Single neuron output:", output)
# Out:
# Single neuron output: 2.3

# %% [markdown]
# Code (Cell 3 — 4 Inputs)

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0

output = (
    inputs[0]*weights[0] +
    inputs[1]*weights[1] +
    inputs[2]*weights[2] +
    inputs[3]*weights[3] +
    bias
)

print("4-input neuron output:", output)
# Out:
# 4-input neuron output: 4.8

# %% [markdown]
# Code (Cell 4 — Multiple Neurons)

# %%
inputs = [1, 2, 3, 2.5]

weights = [
    [0.2, 0.8, -0.5, 1],
    [0.5, -0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87]
]

biases = [2, 3, 0.5]

outputs = []

for neuron_weights, neuron_bias in zip(weights, biases):
    neuron_output = 0
    for n_input, weight in zip(inputs, neuron_weights):
        neuron_output += n_input * weight
    neuron_output += neuron_bias
    outputs.append(neuron_output)

print("Layer outputs (loop):", outputs)
# Out:
# Layer outputs (loop): [4.8, 1.21, 2.385]

# %% [markdown]
# Code (Cell 5 — NumPy Version)

# %%
import numpy as np

inputs = [1.0, 2.0, 3.0, 2.5]
weights = [
    [0.2, 0.8, -0.5, 1],
    [0.5, -0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87]
]
biases = [2.0, 3.0, 0.5]

layer_outputs = np.dot(inputs, np.array(weights).T) + biases
print("Layer outputs (NumPy):", layer_outputs)
# Out:
# Layer outputs (NumPy): [4.8   1.21  2.385]
